# %% [markdown]
# <a href="https://colab.research.google.com/github/younas10/AI_LAB/blob/main/TASK_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TASK NO 1**

# %%
# Multiplication Table Program

# Taking user input
num = int(input("Enter the number: "))
start = int(input("Enter the starting range: "))
end = int(input("Enter the ending range: "))

# Printing the multiplication table
print(f"\nMultiplication Table of {num} from {start} to {end}:")
for i in range(start, end + 1):
    print(f"{num} x {i} = {num * i}")
# Out:
# Enter the number: 5
# Enter the starting range: 1
# Enter the ending range: 10
#
# Multiplication Table of 5 from 1 to 10:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# **TASK NO 2 **
