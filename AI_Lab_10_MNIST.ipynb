# %% [markdown]
# <a href="https://colab.research.google.com/github/younas10/AI_LAB/blob/main/AI_Lab_10_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Younas Ahmad**
#
# **ID # 37302**
#
# **LAB Task : 10**

# %% [markdown]
# **1. Importing Librarie**s

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# **2. Loading MNIST Dataset**

# %%
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# **3. Data Preprocessing**

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# **4. Building the Neural Network**

# %%
model = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10)
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# **5. Compiling the Model**

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %% [markdown]
# **6. Training the Model**

# %%
model.fit(train_images, train_labels, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8433 - loss: 0.5303 - val_accuracy: 0.9570 - val_loss: 0.1534
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9501 - loss: 0.1663 - val_accuracy: 0.9665 - val_loss: 0.1176
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9663 - loss: 0.1172 - val_accuracy: 0.9718 - val_loss: 0.1005
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9726 - loss: 0.0923 - val_accuracy: 0.9728 - val_loss: 0.0923
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9762 - loss: 0.0773 - val_accuracy: 0.9747 - val_loss: 0.0839
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9792 - loss: 0.0650 - val_accuracy: 0.9765 - val_loss: 0.0810
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9807 - loss: 0.0578 - val_accuracy: 0.9761 - val_loss: 0.0815
# Epoch 8/10
# ...

# %% [markdown]
# **7. Evaluating the Model**

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print("\nTest accuracy:", test_acc)
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.9772 - loss: 0.0765
#
# Test accuracy: 0.9771999716758728
