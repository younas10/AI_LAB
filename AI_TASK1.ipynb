# %% [markdown]
# <a href="https://colab.research.google.com/github/younas10/AI_LAB/blob/main/AI_TASK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install & Import**

# %%
# !pip install pandas numpy scikit-learn --quiet

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# **Load Dataset**

# %%
df = pd.read_csv("/content/Banksy.csv", encoding="latin1")  # adjust path if needed
print("Original shape:", df.shape)
df.head()
# Out:
# Original shape: (18, 3)
#                                           Elementary  \
# 0  The auction of a Banksy painting that\ndisappe...
# 1  Slave Labour is a spray-painted artwork that\n...
# 2  But Frederic Thut, the owner of the Fine\nArts...
# 3  People in Haringey, London, were very\nhappy, ...
# 4  I will write to the auction house to find out...
#
#                                         Intermediate  \
# 0  The controversial auction of a Banksy mural\nt...
# 1  Slave Labour is a spray-painted artwork\nshowi...
# 2  But auctioneer Frederic Thut, the owner of\nth...
# 3  He would not give a reason, but community\nlea...
# 4  One of our two demands was that it doesnt\ns...
#
#                                             Advanced
# 0  The controversial auction of a Banksy mural th...
# 1  Slave Labour, a spray-painted artwork depictin...
# 2  But auctioneer Frederic Thut, the owner of the...
# 3  He would not give a reason, but community\nlea...
# 4  One of our two demands was that it doesnt\ns...

# %% [markdown]
# **Handle Missing Values**

# %%
# Fill numeric columns with mean, categorical with mode
for col in df.columns:
    if df[col].dtype == 'O':  # object = text
        df[col].fillna(df[col].mode()[0], inplace=True)
    else:
        df[col].fillna(df[col].mean(), inplace=True)
# Out:
# /tmp/ipython-input-828075528.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %% [markdown]
# **Remove Duplicates**

# %%
df.drop_duplicates(inplace=True)
print("After removing duplicates:", df.shape)
# Out:
# After removing duplicates: (18, 3)

# %% [markdown]
# **Remove Outliers (IQR method)**

# %%
num_cols = df.select_dtypes(include=[np.number]).columns
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower, upper = Q1 - 1.5*IQR, Q3 + 1.5*IQR
    df = df[(df[col] >= lower) & (df[col] <= upper)]

print("After removing outliers:", df.shape)
# Out:
# After removing outliers: (18, 3)

# %% [markdown]
# **Normalize Numeric Columns**

# %%
scaler = MinMaxScaler()
num_cols = df.select_dtypes(include=[np.number]).columns
if len(num_cols) > 0:
    df[num_cols] = scaler.fit_transform(df[num_cols])
else:
    print("No numerical columns found to scale.")
# Out:
# No numerical columns found to scale.

# %% [markdown]
# **Save Cleaned Data**

# %%
df.to_csv("/content/Banksy_cleaned.csv", index=False)
print("Cleaned file saved successfully!")
df.head()
# Out:
# Cleaned file saved successfully!
#                                           Elementary  \
# 0  The auction of a Banksy painting that\ndisappe...
# 1  Slave Labour is a spray-painted artwork that\n...
# 2  But Frederic Thut, the owner of the Fine\nArts...
# 3  People in Haringey, London, were very\nhappy, ...
# 4  I will write to the auction house to find out...
#
#                                         Intermediate  \
# 0  The controversial auction of a Banksy mural\nt...
# 1  Slave Labour is a spray-painted artwork\nshowi...
# 2  But auctioneer Frederic Thut, the owner of\nth...
# 3  He would not give a reason, but community\nlea...
# 4  One of our two demands was that it doesnt\ns...
#
#                                             Advanced
# 0  The controversial auction of a Banksy mural th...
# 1  Slave Labour, a spray-painted artwork depictin...
# 2  But auctioneer Frederic Thut, the owner of the...
# 3  He would not give a reason, but community\nlea...
# 4  One of our two demands was that it doesnt\ns...
